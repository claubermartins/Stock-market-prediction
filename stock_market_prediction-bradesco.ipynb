# %% [markdown]
# <a href="https://colab.research.google.com/github/claubermartins/Stock-market-prediction/blob/main/stock_market_prediction-bradesco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install inflection
# Out:
# Requirement already satisfied: inflection in /usr/local/lib/python3.7/dist-packages (0.5.1)

# %% [markdown]
# #**1-Importando bibliotecas**

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import seaborn as sns
import datetime
import inflection
from IPython.core.display import HTML

# %% [markdown]
# #**2-Funções auxiliares para o Jupyter Notebook**

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #**2.1Método de importação de arquivos do Google Colab**

# %%
from google.colab import files
upload = files.upload()
print("downloaded files: ")
print(*upload, sep = "\n")
# Out:
#      <input type="file" id="files-fdcda4e2-610d-4fb6-af76-e2026f7eb804" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdcda4e2-610d-4fb6-af76-e2026f7eb804">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BBDC4-teste.csv to BBDC4-teste.csv
# Saving BBDC4-treinamento.csv to BBDC4-treinamento.csv
# downloaded files:
# BBDC4-teste.csv
# BBDC4-treinamento.csv

# %% [markdown]
# #**3-Tratamento dos dados**

# %% [markdown]
# ##**3.1-Importando os dados**

# %%
base = pd.read_csv('BBDC4-treinamento.csv')
base = base.drop('Date', axis = 1)

# %%
#valores estatísticos
base.describe()
# Out:
#               Open         High          Low        Close    Adj Close        Volume
# count  2231.000000  2231.000000  2231.000000  2231.000000  2231.000000  2.231000e+03
# mean     16.521398    16.723608    16.310453    16.525766    12.619423  1.526746e+07
# std       4.126155     4.177349     4.065883     4.128200     4.450117  8.569623e+06
# min       9.687407     9.858160     9.636181     9.681715     7.250297  0.000000e+00
# 25%      13.323936    13.466231    13.311944    13.311944     9.156341  1.052012e+07
# 50%      15.382032    15.579269    15.182819    15.358316    10.968378  1.437028e+07
# 75%      18.417855    18.663911    18.153644    18.472953    14.902138  1.914296e+07
# max      29.545454    29.719696    29.106060    29.484848    26.372849  8.762744e+07

# %%
base.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %% [markdown]
# ##**3.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
#       Open  High  Low  Close  Adj Close  Volume
# 2015   NaN   NaN  NaN    NaN        NaN     NaN

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# 333   13.453295  13.453295  13.453295  13.453295   8.892475     0.0
# 337   13.259257  13.259257  13.259257  13.259257   8.764221     0.0
# 450   13.173018  13.173018  13.173018  13.173018   8.778509     0.0
# 451   13.173018  13.173018  13.173018  13.173018   8.778509     0.0
# 452   13.173018  13.173018  13.173018  13.173018   8.778509     0.0
# 461   13.237697  13.237697  13.237697  13.237697   8.826204     0.0
# 482   13.466231  13.466231  13.466231  13.466231   8.983266     0.0
# 507   13.561094  13.561094  13.561094  13.561094   9.238768     0.0
# 799   15.808915  15.808915  15.808915  15.808915  11.126439     0.0
# 819   15.291912  15.291912  15.291912  15.291912  10.768173     0.0
# 881   13.674498  13.674498  13.674498  13.674498   9.718309     0.0
# 1831  19.207989  19.207989  19.207989  19.207989  16.143587     0.0
# 1844  18.691460  18.691460  18.691460  18.691460  15.720361     0.0
# 1904  23.601929  23.601929  23.601929  23.601929  20.021959     0.0
# 1929  25.413223  25.413223  25.413223  25.413223  21.570072     0.0
# 1944  23.140495  23.140495  23.140495  23.140495  19.641043     0.0
# 1946  23.360882  23.360882  23.360882  23.360882  19.839302     0.0
# 1953  22.176308  22.176308  22.176308  22.176308  18.833303     0.0
# 1956  23.154268  23.154268  23.154268  23.154268  19.663834     0.0
# 1981  23.464188  23.464188  23.464188  23.464188  19.938654     0.0
# 1985  23.312672  23.312672  23.312672  23.312672  20.304495     0.0
# 2003  27.410467  27.410467  27.410467  27.410467  23.886627     0.0

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#Verificando novamente se ainda temos valores nulos
base.loc[base['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#base = base.dropna()

# %%
#base.sample()

# %% [markdown]
# #**-Descrição dos dados** IGNORE ESTA CÉLULA

# %%
#Tendencia central - mean, median
ct1 = pd.DataFrame(base.apply(np.mean)).T #T transpondo 
ct2 = pd.DataFrame(base.apply(np.median)).T
#Dispersão - std(desvio padrão), min, max, range
d1 = pd.DataFrame(base.apply(np.std)).T
d2 = pd.DataFrame(base.apply(min)).T
d3 = pd.DataFrame(base.apply(max)).T
d4 = pd.DataFrame(base.apply(lambda x: x.max() - x.min())).T
#concatenate
m = pd.concat([d2,d3,d4,ct1,ct2,d1]).T.reset_index()
m.columns = ['attributes','min','max','range', 'mean', 'median', 'std']
m

# %%
base.shape[0]
# Out:
# 2478

# %% [markdown]
# #**4-Treinamento da rede**

# %%
#normalizando a base de dados com o MinMaxScaler
base_treinamento = base.iloc[:, 0:6].values
normalizador = MinMaxScaler(feature_range=(0,1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
#Comparando a predição com o preço real
previsores = []
preco_real = []
for i in range(90, 2232):
    previsores.append(base_treinamento_normalizada[i-90:i, 0:6])
    preco_real.append(base_treinamento_normalizada[i, 0])
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %%
#estrutura da rede neural 
regressor = Sequential()
regressor.add(LSTM(units = 100, return_sequences = True, input_shape = (previsores.shape[1], 6)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'sigmoid'))

es = EarlyStopping(monitor = 'loss', min_delta = 1e-15, patience = 20, verbose = 1)

#regressor.compile(optimizer = 'RMSprop', loss = 'mean_squared_error',
#                  metrics = ['mean_absolute_error'])
opt = tf.keras.optimizers.Adam(amsgrad=True)
regressor.compile(optimizer = opt, loss = 'mean_squared_error',
                  metrics = ['mean_absolute_error'])
#opt = tf.keras.optimizers.RMSprop(centered=True)
#regressor.compile(optimizer = opt, loss = 'mean_squared_error',
#                 metrics = ['mean_absolute_error'])

regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32,
              callbacks = [es])
#regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32)
# Out:
# Epoch 1/600
# 67/67 [==============================] - 5s 18ms/step - loss: 0.0310 - mean_absolute_error: 0.1368
# Epoch 2/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0048 - mean_absolute_error: 0.0534
# Epoch 3/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0037 - mean_absolute_error: 0.0457
# Epoch 4/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0028 - mean_absolute_error: 0.0405
# Epoch 5/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0028 - mean_absolute_error: 0.0397
# Epoch 6/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0374
# Epoch 7/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0360
# Epoch 8/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0023 - mean_absolute_error: 0.0352
# Epoch 9/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0358
# Epoch 10/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0023 - mean_absolute_error: 0.0348
# Epoch 11/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0020 - mean_absolute_error: 0.0350
# Epoch 12/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0022 - mean_absolute_error: 0.0352
# Epoch 13/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0312
# Epoch 14/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0019 - mean_absolute_error: 0.0329
# Epoch 15/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0310
# Epoch 16/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0312
# Epoch 17/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0288
# Epoch 18/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0295
# Epoch 19/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0303
# Epoch 20/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0282
# Epoch 21/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0018 - mean_absolute_error: 0.0296
# Epoch 22/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0274
# Epoch 23/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0267
# Epoch 24/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0283
# Epoch 25/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0269
# Epoch 26/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0267
# Epoch 27/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0273
# Epoch 28/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0254
# Epoch 29/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0252
# Epoch 30/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0274
# Epoch 31/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0253
# Epoch 32/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0253
# Epoch 33/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.9235e-04 - mean_absolute_error: 0.0241
# Epoch 34/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.8921e-04 - mean_absolute_error: 0.0232
# Epoch 35/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0245
# Epoch 36/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0244
# Epoch 37/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0241
# Epoch 38/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.6586e-04 - mean_absolute_error: 0.0232
# Epoch 39/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.2271e-04 - mean_absolute_error: 0.0227
# Epoch 40/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0010 - mean_absolute_error: 0.0240
# Epoch 41/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.9799e-04 - mean_absolute_error: 0.0236
# Epoch 42/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0242
# Epoch 43/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0228
# Epoch 44/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0228
# Epoch 45/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.3780e-04 - mean_absolute_error: 0.0223
# Epoch 46/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.1129e-04 - mean_absolute_error: 0.0214
# Epoch 47/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.5870e-04 - mean_absolute_error: 0.0221
# Epoch 48/600
# 67/67 [==============================] - 1s 17ms/step - loss: 9.0060e-04 - mean_absolute_error: 0.0219
# Epoch 49/600
# 67/67 [==============================] - 1s 16ms/step - loss: 8.4174e-04 - mean_absolute_error: 0.0221
# Epoch 50/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0211
# Epoch 51/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0225
# Epoch 52/600
# 67/67 [==============================] - 1s 16ms/step - loss: 7.4235e-04 - mean_absolute_error: 0.0207
# Epoch 53/600
# 67/67 [==============================] - 1s 17ms/step - loss: 8.9510e-04 - mean_absolute_error: 0.0218
# Epoch 54/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.0093e-04 - mean_absolute_error: 0.0210
# Epoch 55/600
# 67/67 [==============================] - 1s 16ms/step - loss: 7.4353e-04 - mean_absolute_error: 0.0205
# Epoch 56/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0010 - mean_absolute_error: 0.0216
# Epoch 57/600
# 67/67 [==============================] - 1s 16ms/step - loss: 8.4005e-04 - mean_absolute_error: 0.0216
# Epoch 58/600
# 67/67 [==============================] - 1s 16ms/step - loss: 9.4640e-04 - mean_absolute_error: 0.0211
# Epoch 59/600
# 67/67 [==============================] - 1s 16ms/step - loss: 8.4725e-04 - mean_absolute_error: 0.0208
# Epoch 60/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0213
# Epoch 61/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0209
# Epoch 62/600
# 67/67 [==============================] - 1s 16ms/step - loss: 7.6689e-04 - mean_absolute_error: 0.0200
# Epoch 63/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0220
# Epoch 64/600
# 67/67 [==============================] - 1s 16ms/step - loss: 6.9404e-04 - mean_absolute_error: 0.0199
# Epoch 65/600
# 67/67 [==============================] - 1s 16ms/step - loss: 8.3287e-04 - mean_absolute_error: 0.0214
# Epoch 66/600
# 67/67 [==============================] - 1s 16ms/step - loss: 8.1991e-04 - mean_absolute_error: 0.0207
# Epoch 67/600
# 67/67 [==============================] - 1s 17ms/step - loss: 9.1244e-04 - mean_absolute_error: 0.0211
# Epoch 68/600
# 67/67 [==============================] - 1s 16ms/step - loss: 6.9251e-04 - mean_absolute_error: 0.0192
# Epoch 69/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.
# Epoch 00124: early stopping

# %% [markdown]
# #**5-Teste da rede**

# %% [markdown]
# ##**5.1-Importando os dados para teste**

# %%
#criando a base de dados teste
base_teste = pd.read_csv('BBDC4-teste.csv')
base_teste = base_teste.drop('Date', axis = 1)

# %%
#valores estatísticos
base_teste.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  247.000000  247.000000  247.000000  247.000000  247.000000  2.470000e+02
# mean    32.119408   32.470714   31.702913   32.114507   29.294712  2.005127e+07
# std      1.582360    1.564653    1.546998    1.574365    1.421719  7.561476e+06
# min     28.836363   29.236362   28.509090   28.763636   26.142099  8.201050e+06
# 25%     30.854546   31.227272   30.536362   30.936363   28.326915  1.476304e+07
# 50%     31.916666   32.281818   31.563637   31.962120   29.204481  1.841323e+07
# 75%     33.359848   33.734091   32.804544   33.222727   30.359981  2.392137e+07
# max     36.000000   36.309090   35.472729   35.827271   32.543896  5.922169e+07

# %% [markdown]
# ##**5.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base_teste.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
#     Open  High  Low  Close  Adj Close  Volume
# 42   NaN   NaN  NaN    NaN        NaN     NaN

# %%
#preenchendo os valores faltantes com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# #**5.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base_teste == 0).sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Encontrando os valores nulos
base_teste.loc[base_teste['Volume'] == 0]

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#Verificando novamente se tem valores nulos
base_teste.loc[base_teste['Volume'] == 0]

# %% [markdown]
# ##**5.4-Preparando a estrutura para teste**

# %%
#concatenando a base de dados teste com o base de treinamento
preco_real_teste = base_teste.iloc[:, 3:4].values
frames = [base, base_teste]
base_completa = pd.concat(frames)

# %%
#pegando os 90 registros anteriores para percorrer a base teste e colocando no
#no formato np.array
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)
Percorrer_teste = []
for i in range(90, 338): 
    Percorrer_teste.append(entradas[i-90:i, 0:6])
Percorrer_teste = np.array(Percorrer_teste)

# %%
#resultado da predição no formato MinMaxScaler
previsoes = regressor.predict(Percorrer_teste)

# %%
#convertendo para a escala MinMaxScaler 
normalizador_previsao = MinMaxScaler(feature_range=(0,1))
normalizador_previsao.fit_transform(base_treinamento[:,3:4])
# Out:
# array([[0.32860083],
#        [0.32426404],
#        [0.31775871],
#        ...,
#        [0.91124758],
#        [0.94376466],
#        [0.98967103]])

# %%
#colocando a previsão no formato original para preparar a visualização no gráfico
previsoes = normalizador_previsao.inverse_transform(previsoes)
previsoes
# Out:
# array([[28.518353],
#        [28.75868 ],
#        [28.927757],
#        [29.028378],
#        [29.09583 ],
#        [29.139982],
#        [29.173775],
#        [29.199593],
#        [29.216343],
#        [29.228895],
#        [29.238907],
#        [29.246235],
#        [29.252953],
#        [29.258793],
#        [29.264553],
#        [29.26815 ],
#        [29.271273],
#        [29.274794],
#        [29.278406],
#        [29.282059],
#        [29.284992],
#        [29.28711 ],
#        [29.29119 ],
#        [29.293953],
#        [29.296938],
#        [29.299536],
#        [29.30093 ],
#        [29.302324],
#        [29.303425],
#        [29.304132],
#        [29.305164],
#        [29.30567 ],
#        [29.306532],
#        [29.30732 ],
#        [29.307821],
#        [29.308428],
#        [29.308722],
#        [29.309137],
#        [29.309366],
#        [29.309431],
#        [29.309652],
#        [29.309763],
#        [29.309612],
#        [29.309155],
#        [29.308613],
#        [29.307878],
#        [29.307419],
#        [29.307844],
#        [29.308191],
#        [29.308846],
#        [29.309397],
#        [29.310019],
#        [29.310654],
#        [29.311134],
#        [29.311321],
#        [29.311142],
#        [29.309849],
#        [29.30869 ],
#        [29.307465],
#        [29.304388],
#        [29.303776],
#        [29.303064],
#        [29.303513],
#        [29.303247],
#        [29.302998],
#        [29.303349],
#        [29.303823],
#        [29.304441],
#        [29.304878],
#        [29.305193],
#        [29.304777],
#        [29.303919],
#        [29.302504],
#        [29.300627],
#        [29.296926],
#        [29.29441 ],
#        [29.291965],
#        [29.292393],
#        [29.292252],
#        [29.293442],
#        [29.2946  ],
#        [29.295263],
#        [29.295784],
#        [29.295956],
#        [29.296831],
#        [29.296003],
#        [29.29442 ],
#        [29.294226],
#        [29.291927],
#        [29.289343],
#        [29.282778],
#        [29.27487 ],
#        [29.261852],
#        [29.247469],
#        [29.237469],
#        [29.23779 ],
#        [29.24432 ],
#        [29.249   ],
#        [29.25279 ],
#        [29.255266],
#        [29.259653],
#        [29.265388],
#        [29.271961],
#        [29.27848 ],
#        [29.284029],
#        [29.288588],
#        [29.292477],
#        [29.295143],
#        [29.297743],
#        [29.29989 ],
#        [29.301348],
#        [29.302761],
#        [29.303734],
#        [29.304287],
#        [29.304613],
#        [29.304714],
#        [29.304962],
#        [29.305153],
#        [29.30585 ],
#        [29.306614],
#        [29.307257],
#        [29.308035],
#        [29.308617],
#        [29.309202],
#        [29.309671],
#        [29.310032],
#        [29.310396],
#        [29.310858],
#        [29.311302],
#        [29.311705],
#        [29.312109],
#        [29.312403],
#        [29.312624],
#        [29.31275 ],
#        [29.31284 ],
#        [29.312828],
#        [29.313002],
#        [29.312922],
#        [29.31302 ],
#        [29.313038],
#        [29.313337],
#        [29.313017],
#        [29.312761],
#        [29.312256],
#        [29.311285],
#        [29.309864],
#        [29.308401],
#        [29.306736],
#        [29.304167],
#        [29.302614],
#        [29.301243],
#        [29.300634],
#        [29.299376],
#        [29.2968  ],
#        [29.29533 ],
#        [29.291092],
#        [29.287466],
#        [29.28295 ],
#        [29.276392],
#        [29.269447],
#        [29.264107],
#        [29.253351],
#        [29.235405],
#        [29.211555],
#        [29.176579],
#        [29.144003],
#        [29.126554],
#        [29.111645],
#        [29.08599 ],
#        [29.06903 ],
#        [29.078823],
#        [29.11048 ],
#        [29.147387],
#        [29.17515 ],
#        [29.193075],
#        [29.205082],
#        [29.208527],
#        [29.202288],
#        [29.194624],
#        [29.192234],
#        [29.18919 ],
#        [29.190506],
#        [29.194952],
#        [29.197117],
#        [29.198706],
#        [29.20338 ],
#        [29.210596],
#        [29.21512 ],
#        [29.215015],
#        [29.198198],
#        [29.166288],
#        [29.13097 ],
#        [29.099415],
#        [29.075205],
#        [29.079922],
#        [29.100292],
#        [29.125929],
#        [29.153872],
#        [29.178755],
#        [29.201874],
#        [29.221342],
#        [29.233126],
#        [29.238464],
#        [29.243818],
#        [29.25024 ],
#        [29.256792],
#        [29.26297 ],
#        [29.269659],
#        [29.2769  ],
#        [29.282589],
#        [29.287651],
#        [29.290014],
#        [29.291777],
#        [29.292343],
#        [29.292957],
#        [29.292946],
#        [29.293087],
#        [29.290789],
#        [29.287834],
#        [29.282297],
#        [29.274828],
#        [29.266006],
#        [29.255861],
#        [29.246328],
#        [29.2407  ],
#        [29.238113],
#        [29.23195 ],
#        [29.226011],
#        [29.22002 ],
#        [29.213928],
#        [29.213482],
#        [29.215044],
#        [29.221922],
#        [29.232384],
#        [29.241034],
#        [29.247639],
#        [29.25342 ],
#        [29.257235],
#        [29.260021],
#        [29.263712],
#        [29.267084],
#        [29.268751],
#        [29.272242],
#        [29.27688 ],
#        [29.282068],
#        [29.285942],
#        [29.289587],
#        [29.292957]], dtype=float32)

# %% [markdown]
# ##**6-Análise dos resuldatos**

# %%
#Visualizando o gráfico da Previsão da rede
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão do preço das ações')
plt.xlabel('Tempo em dias')
plt.ylabel('Preço das ações')
plt.legend()
plt.show()

# %%
#estatísticas do preço real comparado com a previsão
df1 = pd.DataFrame(preco_real_teste).T
df2 = pd.DataFrame(previsoes).T

df3 = pd.concat([df1,df2]).T
df3.columns = ['Preco real', 'Previsoes']
df3.describe()
# Out:
#        Preco real   Previsoes
# count  248.000000  248.000000
# mean    32.114507   29.257852
# std      1.571175    0.084029
# min     28.763636   28.518353
# 25%     30.936363   29.238796
# 50%     31.967424   29.290401
# 75%     33.202271   29.304899
# max     35.827271   29.313337

# %%
#df2 = pd.DataFrame(previsoes)
#df2.describe()

# %%
#df1 = pd.DataFrame(preco_real_teste)
#df1.describe()
