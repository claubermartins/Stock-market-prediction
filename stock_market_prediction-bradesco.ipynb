# %% [markdown]
# <a href="https://colab.research.google.com/github/claubermartins/Stock-market-prediction/blob/main/stock_market_prediction-bradesco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install inflection
# Out:
# Requirement already satisfied: inflection in /usr/local/lib/python3.7/dist-packages (0.5.1)

# %% [markdown]
# #**1-Importando bibliotecas**

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import seaborn as sns
import datetime
import inflection
from IPython.core.display import HTML

# %% [markdown]
# #**2-Funções auxiliares para o Jupyter Notebook**

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ##**2.1Método de importação de arquivos do Google Colab**

# %%
from google.colab import files
upload = files.upload()
print("downloaded files: ")
print(*upload, sep = "\n")
# Out:
#      <input type="file" id="files-18a0be7a-afef-43ca-9192-73a435d59961" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18a0be7a-afef-43ca-9192-73a435d59961">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BBDC4-teste.csv to BBDC4-teste.csv
# Saving BBDC4-treinamento.csv to BBDC4-treinamento.csv
# downloaded files:
# BBDC4-teste.csv
# BBDC4-treinamento.csv

# %% [markdown]
# #**3-Tratamento dos dados**

# %% [markdown]
# ##**3.1-Importando os dados**

# %%
base = pd.read_csv('BBDC4-treinamento.csv')
base = base.drop('Date', axis = 1)

# %%
#valores estatísticos
base.describe()
# Out:
#               Open         High          Low        Close    Adj Close        Volume  media_movel
# count  2231.000000  2231.000000  2231.000000  2231.000000  2231.000000  2.231000e+03  2232.000000
# mean     16.521398    16.723608    16.310453    16.525766    12.619423  1.526746e+07    16.521145
# std       4.126155     4.177349     4.065883     4.128200     4.450117  8.569623e+06     4.118673
# min       9.687407     9.858160     9.636181     9.681715     7.250297  0.000000e+00     9.738633
# 25%      13.323936    13.466231    13.311944    13.311944     9.156341  1.052012e+07    13.312314
# 50%      15.382032    15.579269    15.182819    15.358316    10.968378  1.437028e+07    15.377289
# 75%      18.417855    18.663911    18.153644    18.472953    14.902138  1.914296e+07    18.439038
# max      29.545454    29.719696    29.106060    29.484848    26.372849  8.762744e+07    29.204545

# %%
base.dtypes
# Out:
# Open           float64
# High           float64
# Low            float64
# Close          float64
# Adj Close      float64
# Volume         float64
# media_movel    float64
# dtype: object

# %% [markdown]
# ##**3.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base.isna().sum()
# Out:
# Open           1
# High           1
# Low            1
# Close          1
# Adj Close      1
# Volume         1
# media_movel    0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
base.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:7])
base.iloc[:,0:7] = imputer.transform(base.iloc[:,0:7])

# %%
#verificando novamente se ainda temos valores faltantes
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
base.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %% [markdown]
# ##**3.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base == 0).sum()
# Out:
# Open             0
# High             0
# Low              0
# Close            0
# Adj Close        0
# Volume         135
# media_movel      0
# dtype: int64

# %%
#Encontrando os valores nulos
base.loc[base['Volume'] == 0]
# Out:
#            Open       High        Low      Close  Adj Close  Volume  media_movel
# 34    13.311944  13.311944  13.311944  13.311944   8.555276     0.0    13.540967
# 35    13.311944  13.311944  13.311944  13.311944   8.555276     0.0    13.383514
# 36    13.311944  13.311944  13.311944  13.311944   8.555276     0.0    13.311944
# 37    13.311944  13.311944  13.311944  13.311944   8.555276     0.0    13.311944
# 38    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 39    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 40    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 41    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 42    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 43    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 44    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 45    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 46    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 47    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 48    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 49    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 50    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 51    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 52    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 53    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 54    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 55    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 56    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 57    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 58    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 59    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 60    13.311944  13.311944  13.311944  13.311944   8.559290     0.0    13.311944
# 61    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 62    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 63    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 64    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 65    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 66    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 67    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 68    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 69    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 70    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 71    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 72    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 73    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 74    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 75    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 76    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 77    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 78    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 79    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 80    13.311944  13.311944  13.311944  13.311944   8.563306     0.0    13.311944
# 81    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 82    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 83    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 84    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 85    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 86    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 87    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 88    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 89    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 90    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 91    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 92    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 93    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 94    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 95    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 96    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 97    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 98    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 99    13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 100   13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 101   13.311944  13.311944  13.311944  13.311944   8.567323     0.0    13.311944
# 102   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 103   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 104   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 105   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 106   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 107   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 108   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 109   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 110   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 111   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 112   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 113   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 114   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 115   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 116   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 117   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 118   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 119   13.311944  13.311944  13.311944  13.311944   8.571342     0.0    13.311944
# 120   13.311944  13.311944  13.311944  13.311944   8.611738     0.0    13.311944
# 121   13.311944  13.311944  13.311944  13.311944   8.611738     0.0    13.311944
# 122   13.311944  13.311944  13.311944  13.311944   8.611738     0.0    13.311944
# 123   13.311944  13.311944  13.311944  13.311944   8.615780     0.0    13.311944
# 124   13.311944  13.311944  13.311944  13.311944   8.615780     0.0    13.311944
# 125   13.311944  13.311944  13.311944  13.311944   8.615780     0.0    13.311944
# 126   13.311944  13.311944  13.311944  13.311944   8.615780     0.0    13.311944
# 127   13.311944  13.311944  13.311944  13.311944   8.615780     0.0    13.311944
# 275   12.849621  12.849621  12.849621  12.849621   8.456571     0.0    12.895616
# 276   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.843872
# 277   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 278   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 279   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 280   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 281   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 282   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 283   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 284   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 285   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 286   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 287   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 288   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 289   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 290   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 291   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 308   13.992289  13.992289  13.992289  13.992289   9.240288     0.0    13.753694
# 310   14.315686  14.315686  14.315686  14.315686   9.458089     0.0    14.258193
# 333   13.453295  13.453295  13.453295  13.453295   8.892475     0.0    13.410175
# 337   13.259257  13.259257  13.259257  13.259257   8.764221     0.0    13.437484
# 450   13.173018  13.173018  13.173018  13.173018   8.778509     0.0    12.908551
# 451   13.173018  13.173018  13.173018  13.173018   8.778509     0.0    13.093965
# 452   13.173018  13.173018  13.173018  13.173018   8.778509     0.0    13.173018
# 461   13.237697  13.237697  13.237697  13.237697   8.826204     0.0    13.270755
# 482   13.466231  13.466231  13.466231  13.466231   8.983266     0.0    13.438922
# 507   13.561094  13.561094  13.561094  13.561094   9.238768     0.0    13.592715
# 799   15.808915  15.808915  15.808915  15.808915  11.126439     0.0    15.491124
# 819   15.291912  15.291912  15.291912  15.291912  10.768173     0.0    15.459503
# 881   13.674498  13.674498  13.674498  13.674498   9.718309     0.0    13.663431
# 1831  19.207989  19.207989  19.207989  19.207989  16.143587     0.0    19.065656
# 1844  18.691460  18.691460  18.691460  18.691460  15.720361     0.0    18.388429
# 1904  23.601929  23.601929  23.601929  23.601929  20.021959     0.0    23.666208
# 1929  25.413223  25.413223  25.413223  25.413223  21.570072     0.0    25.376491
# 1944  23.140495  23.140495  23.140495  23.140495  19.641043     0.0    23.790174
# 1946  23.360882  23.360882  23.360882  23.360882  19.839302     0.0    23.236914
# 1953  22.176308  22.176308  22.176308  22.176308  18.833303     0.0    22.497703
# 1956  23.154268  23.154268  23.154268  23.154268  19.663834     0.0    22.695132
# 1981  23.464188  23.464188  23.464188  23.464188  19.938654     0.0    23.172635
# 1985  23.312672  23.312672  23.312672  23.312672  20.304495     0.0    23.147383
# 2003  27.410467  27.410467  27.410467  27.410467  23.886627     0.0    26.478420

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:7])
base.iloc[:,0:7] = imputer.transform(base.iloc[:,0:7])

# %%
#Verificando novamente se ainda temos valores nulos
base.loc[base['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#base = base.dropna()

# %%
#base.sample()

# %% [markdown]
# #**-Descrição dos dados** IGNORE ESTA CÉLULA

# %%
#Tendencia central - mean, median
ct1 = pd.DataFrame(base.apply(np.mean)).T #T transpondo 
ct2 = pd.DataFrame(base.apply(np.median)).T
#Dispersão - std(desvio padrão), min, max, range
d1 = pd.DataFrame(base.apply(np.std)).T
d2 = pd.DataFrame(base.apply(min)).T
d3 = pd.DataFrame(base.apply(max)).T
d4 = pd.DataFrame(base.apply(lambda x: x.max() - x.min())).T
#concatenate
m = pd.concat([d2,d3,d4,ct1,ct2,d1]).T.reset_index()
m.columns = ['attributes','min','max','range', 'mean', 'median', 'std']
m

# %%
base.shape[0]
# Out:
# 2478

# %% [markdown]
# #**4-Treinamento da rede**

# %%
#normalizando a base de dados com o MinMaxScaler
base_treinamento = base.iloc[:, 0:7].values
normalizador = MinMaxScaler(feature_range=(0,1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
#Comparando a predição com o preço real
previsores = []
preco_real = []
for i in range(90, 2232):
    previsores.append(base_treinamento_normalizada[i-90:i, 0:7])
    preco_real.append(base_treinamento_normalizada[i, 3:4])
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %%
#estrutura da rede neural 
regressor = Sequential()
regressor.add(LSTM(units = 90, return_sequences = True, input_shape = (previsores.shape[1], 7)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 90, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 90, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 90))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'sigmoid'))

es = EarlyStopping(monitor = 'loss', min_delta = 1e-15, patience = 20, verbose = 1)

#regressor.compile(optimizer = 'RMSprop', loss = 'mean_squared_error',
#                  metrics = ['mean_absolute_error'])
opt = tf.keras.optimizers.Adam(amsgrad=True)
regressor.compile(optimizer = opt, loss = 'mean_squared_error',
                  metrics = ['mean_absolute_error'])
#opt = tf.keras.optimizers.RMSprop(centered=True)
#regressor.compile(optimizer = opt, loss = 'mean_squared_error',
#                 metrics = ['mean_absolute_error'])

regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32,
              callbacks = [es])
#regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32)
# Out:
# Epoch 1/600
# 67/67 [==============================] - 13s 98ms/step - loss: 0.0123 - mean_absolute_error: 0.0783
# Epoch 2/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0040 - mean_absolute_error: 0.0480
# Epoch 3/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0033 - mean_absolute_error: 0.0440
# Epoch 4/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0027 - mean_absolute_error: 0.0397
# Epoch 5/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0024 - mean_absolute_error: 0.0376
# Epoch 6/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0022 - mean_absolute_error: 0.0356
# Epoch 7/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0022 - mean_absolute_error: 0.0352
# Epoch 8/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0020 - mean_absolute_error: 0.0333
# Epoch 9/600
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0021 - mean_absolute_error: 0.0347
# Epoch 10/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0021 - mean_absolute_error: 0.0349
# Epoch 11/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0018 - mean_absolute_error: 0.0319
# Epoch 12/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0018 - mean_absolute_error: 0.0314
# Epoch 13/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0017 - mean_absolute_error: 0.0306
# Epoch 14/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0016 - mean_absolute_error: 0.0301
# Epoch 15/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0015 - mean_absolute_error: 0.0291
# Epoch 16/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0016 - mean_absolute_error: 0.0295
# Epoch 17/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0014 - mean_absolute_error: 0.0268
# Epoch 18/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0015 - mean_absolute_error: 0.0283
# Epoch 19/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0014 - mean_absolute_error: 0.0277
# Epoch 20/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0013 - mean_absolute_error: 0.0266
# Epoch 21/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0014 - mean_absolute_error: 0.0274
# Epoch 22/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0013 - mean_absolute_error: 0.0265
# Epoch 23/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0012 - mean_absolute_error: 0.0256
# Epoch 24/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0012 - mean_absolute_error: 0.0259
# Epoch 25/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0012 - mean_absolute_error: 0.0253
# Epoch 26/600
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0012 - mean_absolute_error: 0.0259
# Epoch 27/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0012 - mean_absolute_error: 0.0257
# Epoch 28/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0248
# Epoch 29/600
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0012 - mean_absolute_error: 0.0246
# Epoch 30/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0236
# Epoch 31/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0244
# Epoch 32/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0010 - mean_absolute_error: 0.0229
# Epoch 33/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0240
# Epoch 34/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0236
# Epoch 35/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0236
# Epoch 36/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0242
# Epoch 37/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0238
# Epoch 38/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0245
# Epoch 39/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0010 - mean_absolute_error: 0.0232
# Epoch 40/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0011 - mean_absolute_error: 0.0234
# Epoch 41/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.5558e-04 - mean_absolute_error: 0.0221
# Epoch 42/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.7213e-04 - mean_absolute_error: 0.0222
# Epoch 43/600
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0010 - mean_absolute_error: 0.0226
# Epoch 44/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.8239e-04 - mean_absolute_error: 0.0220
# Epoch 45/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.7780e-04 - mean_absolute_error: 0.0220
# Epoch 46/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.3637e-04 - mean_absolute_error: 0.0215
# Epoch 47/600
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0010 - mean_absolute_error: 0.0228
# Epoch 48/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.0409e-04 - mean_absolute_error: 0.0214
# Epoch 49/600
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0010 - mean_absolute_error: 0.0225
# Epoch 50/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.1885e-04 - mean_absolute_error: 0.0211
# Epoch 51/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.5993e-04 - mean_absolute_error: 0.0210
# Epoch 52/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.5903e-04 - mean_absolute_error: 0.0216
# Epoch 53/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.3036e-04 - mean_absolute_error: 0.0215
# Epoch 54/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.1482e-04 - mean_absolute_error: 0.0212
# Epoch 55/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.6779e-04 - mean_absolute_error: 0.0218
# Epoch 56/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.4451e-04 - mean_absolute_error: 0.0215
# Epoch 57/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.6759e-04 - mean_absolute_error: 0.0206
# Epoch 58/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.1916e-04 - mean_absolute_error: 0.0214
# Epoch 59/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.1273e-04 - mean_absolute_error: 0.0214
# Epoch 60/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.1319e-04 - mean_absolute_error: 0.0214
# Epoch 61/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.3661e-04 - mean_absolute_error: 0.0217
# Epoch 62/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.9358e-04 - mean_absolute_error: 0.0227
# Epoch 63/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.0318e-04 - mean_absolute_error: 0.0210
# Epoch 64/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.0581e-04 - mean_absolute_error: 0.0212
# Epoch 65/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.1482e-04 - mean_absolute_error: 0.0212
# Epoch 66/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.2640e-04 - mean_absolute_error: 0.0212
# Epoch 67/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.4266e-04 - mean_absolute_error: 0.0203
# Epoch 68/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.5303e-04 - mean_absolute_error: 0.0201
# Epoch 69/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.5933e-04 - mean_absolute_error: 0.0207
# Epoch 70/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.5663e-04 - mean_absolute_error: 0.0202
# Epoch 71/600
# 67/67 [==============================] - 7s 99ms/step - loss: 9.0205e-04 - mean_absolute_error: 0.0206
# Epoch 72/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.4346e-04 - mean_absolute_error: 0.0203
# Epoch 73/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.3084e-04 - mean_absolute_error: 0.0199
# Epoch 74/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.0002e-04 - mean_absolute_error: 0.0211
# Epoch 75/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.2102e-04 - mean_absolute_error: 0.0200
# Epoch 76/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.6892e-04 - mean_absolute_error: 0.0207
# Epoch 77/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.1843e-04 - mean_absolute_error: 0.0197
# Epoch 78/600
# 67/67 [==============================] - 7s 101ms/step - loss: 8.6219e-04 - mean_absolute_error: 0.0204
# Epoch 79/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.3901e-04 - mean_absolute_error: 0.0202
# Epoch 80/600
# 67/67 [==============================] - 7s 100ms/step - loss: 9.4003e-04 - mean_absolute_error: 0.0216
# Epoch 81/600
# 67/67 [==============================] - 7s 101ms/step - loss: 7.9052e-04 - mean_absolute_error: 0.0193
# Epoch 82/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.2894e-04 - mean_absolute_error: 0.0204
# Epoch 83/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.1345e-04 - mean_absolute_error: 0.0195
# Epoch 84/600
# 67/67 [==============================] - 7s 101ms/step - loss: 8.5065e-04 - mean_absolute_error: 0.0203
# Epoch 85/600
# 67/67 [==============================] - 7s 101ms/step - loss: 8.1780e-04 - mean_absolute_error: 0.0200
# Epoch 86/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.2284e-04 - mean_absolute_error: 0.0197
# Epoch 87/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.9578e-04 - mean_absolute_error: 0.0209
# Epoch 88/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.6808e-04 - mean_absolute_error: 0.0207
# Epoch 89/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.4209e-04 - mean_absolute_error: 0.0204
# Epoch 90/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.2772e-04 - mean_absolute_error: 0.0200
# Epoch 91/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.0614e-04 - mean_absolute_error: 0.0197
# Epoch 92/600
# 67/67 [==============================] - 7s 101ms/step - loss: 8.1357e-04 - mean_absolute_error: 0.0199
# Epoch 93/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.5226e-04 - mean_absolute_error: 0.0205
# Epoch 94/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.3080e-04 - mean_absolute_error: 0.0203
# Epoch 95/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.7854e-04 - mean_absolute_error: 0.0205
# Epoch 96/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.3164e-04 - mean_absolute_error: 0.0199
# Epoch 97/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.7829e-04 - mean_absolute_error: 0.0190
# Epoch 98/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.5439e-04 - mean_absolute_error: 0.0201
# Epoch 99/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.8933e-04 - mean_absolute_error: 0.0191
# Epoch 100/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.5349e-04 - mean_absolute_error: 0.0202
# Epoch 101/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.8218e-04 - mean_absolute_error: 0.0196
# Epoch 102/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.7312e-04 - mean_absolute_error: 0.0190
# Epoch 103/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.0958e-04 - mean_absolute_error: 0.0195
# Epoch 104/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.7712e-04 - mean_absolute_error: 0.0193
# Epoch 105/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.3077e-04 - mean_absolute_error: 0.0199
# Epoch 106/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.8962e-04 - mean_absolute_error: 0.0199
# Epoch 107/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.0035e-04 - mean_absolute_error: 0.0192
# Epoch 108/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.9571e-04 - mean_absolute_error: 0.0193
# Epoch 109/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.8825e-04 - mean_absolute_error: 0.0195
# Epoch 110/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.5534e-04 - mean_absolute_error: 0.0191
# Epoch 111/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.7617e-04 - mean_absolute_error: 0.0195
# Epoch 112/600
# 67/67 [==============================] - 7s 98ms/step - loss: 8.4416e-04 - mean_absolute_error: 0.0198
# Epoch 113/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.2618e-04 - mean_absolute_error: 0.0196
# Epoch 114/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.2129e-04 - mean_absolute_error: 0.0197
# Epoch 115/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.6803e-04 - mean_absolute_error: 0.0193
# Epoch 116/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.5044e-04 - mean_absolute_error: 0.0186
# Epoch 117/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.0619e-04 - mean_absolute_error: 0.0194
# Epoch 118/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.9101e-04 - mean_absolute_error: 0.0192
# Epoch 119/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.9698e-04 - mean_absolute_error: 0.0193
# Epoch 120/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.5175e-04 - mean_absolute_error: 0.0189
# Epoch 121/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.4243e-04 - mean_absolute_error: 0.0186
# Epoch 122/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.6705e-04 - mean_absolute_error: 0.0191
# Epoch 123/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.7722e-04 - mean_absolute_error: 0.0194
# Epoch 124/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.0119e-04 - mean_absolute_error: 0.0195
# Epoch 125/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.5498e-04 - mean_absolute_error: 0.0187
# Epoch 126/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.9019e-04 - mean_absolute_error: 0.0193
# Epoch 127/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.9830e-04 - mean_absolute_error: 0.0195
# Epoch 128/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.0708e-04 - mean_absolute_error: 0.0190
# Epoch 129/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.1591e-04 - mean_absolute_error: 0.0194
# Epoch 130/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.4279e-04 - mean_absolute_error: 0.0186
# Epoch 131/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.7908e-04 - mean_absolute_error: 0.0192
# Epoch 132/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.8692e-04 - mean_absolute_error: 0.0197
# Epoch 133/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.9767e-04 - mean_absolute_error: 0.0197
# Epoch 134/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.7297e-04 - mean_absolute_error: 0.0191
# Epoch 135/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.0953e-04 - mean_absolute_error: 0.0200
# Epoch 136/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.4952e-04 - mean_absolute_error: 0.0189
# Epoch 137/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.4840e-04 - mean_absolute_error: 0.0191
# Epoch 138/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.1082e-04 - mean_absolute_error: 0.0190
# Epoch 139/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.9682e-04 - mean_absolute_error: 0.0195
# Epoch 140/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.5652e-04 - mean_absolute_error: 0.0188
# Epoch 141/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.2734e-04 - mean_absolute_error: 0.0189
# Epoch 142/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.3971e-04 - mean_absolute_error: 0.0186
# Epoch 143/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.6004e-04 - mean_absolute_error: 0.0190
# Epoch 144/600
# 67/67 [==============================] - 7s 100ms/step - loss: 8.2796e-04 - mean_absolute_error: 0.0197
# Epoch 145/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.5004e-04 - mean_absolute_error: 0.0189
# Epoch 146/600
# 67/67 [==============================] - 7s 98ms/step - loss: 7.6349e-04 - mean_absolute_error: 0.0188
# Epoch 147/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.6409e-04 - mean_absolute_error: 0.0190
# Epoch 148/600
# 67/67 [==============================] - 7s 98ms/step - loss: 7.5448e-04 - mean_absolute_error: 0.0190
# Epoch 149/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.3813e-04 - mean_absolute_error: 0.0184
# Epoch 150/600
# 67/67 [==============================] - 7s 98ms/step - loss: 7.1751e-04 - mean_absolute_error: 0.0187
# Epoch 151/600
# 67/67 [==============================] - 7s 98ms/step - loss: 7.5799e-04 - mean_absolute_error: 0.0191
# Epoch 152/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.5869e-04 - mean_absolute_error: 0.0189
# Epoch 153/600
# 67/67 [==============================] - 7s 98ms/step - loss: 8.0335e-04 - mean_absolute_error: 0.0193
# Epoch 154/600
# 67/67 [==============================] - 7s 99ms/step - loss: 8.2391e-04 - mean_absolute_error: 0.0197
# Epoch 155/600
# 67/67 [==============================] - 7s 99ms/step - loss: 6.9106e-04 - mean_absolute_error: 0.0181
# Epoch 156/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.2060e-04 - mean_absolute_error: 0.0182
# Epoch 157/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.4340e-04 - mean_absolute_error: 0.0186
# Epoch 158/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.4962e-04 - mean_absolute_error: 0.0187
# Epoch 159/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.3577e-04 - mean_absolute_error: 0.0188
# Epoch 160/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.4938e-04 - mean_absolute_error: 0.0186
# Epoch 161/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.4462e-04 - mean_absolute_error: 0.0185
# Epoch 162/600
# 67/67 [==============================] - 7s 100ms/step - loss: 6.9459e-04 - mean_absolute_error: 0.0180
# Epoch 163/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.3758e-04 - mean_absolute_error: 0.0188
# Epoch 164/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.4332e-04 - mean_absolute_error: 0.0186
# Epoch 165/600
# 67/67 [==============================] - 7s 101ms/step - loss: 7.4673e-04 - mean_absolute_error: 0.0186
# Epoch 166/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.1512e-04 - mean_absolute_error: 0.0186
# Epoch 167/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.6085e-04 - mean_absolute_error: 0.0187
# Epoch 168/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.1216e-04 - mean_absolute_error: 0.0183
# Epoch 169/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.3774e-04 - mean_absolute_error: 0.0185
# Epoch 170/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.1635e-04 - mean_absolute_error: 0.0182
# Epoch 171/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.9570e-04 - mean_absolute_error: 0.0196
# Epoch 172/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.3556e-04 - mean_absolute_error: 0.0185
# Epoch 173/600
# 67/67 [==============================] - 7s 100ms/step - loss: 7.7525e-04 - mean_absolute_error: 0.0192
# Epoch 174/600
# 67/67 [==============================] - 7s 99ms/step - loss: 7.5332e-04 - mean_absolute_error: 0.0190
# Epoch 175/600
# 67/67 [==============================] - 7s 98ms/step - loss: 7.5868e-04 - mean_absolute_error: 0.0186
# Epoch 00175: early stopping

# %% [markdown]
# #**5-Teste da rede**

# %% [markdown]
# ##**5.1-Importando os dados para teste**

# %%
#criando a base de dados teste
base_teste = pd.read_csv('BBDC4-teste.csv')
base_teste = base_teste.drop('Date', axis = 1)

# %%
#valores estatísticos
base_teste.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume  media_movel
# count  247.000000  247.000000  247.000000  247.000000  247.000000  2.470000e+02   247.000000
# mean    32.119312   32.470891   31.703077   32.114413   29.294737  2.005127e+07    32.109433
# std      1.582138    1.564298    1.546993    1.574197    1.422042  7.561476e+06     1.543941
# min     28.840000   29.240000   28.510000   28.760000   26.140000  8.201050e+06    29.000000
# 25%     30.850000   31.230000   30.535000   30.940000   28.325000  1.476304e+07    30.930000
# 50%     31.920000   32.280000   31.560000   31.960000   29.200000  1.841323e+07    31.900000
# 75%     33.360000   33.735000   32.805000   33.220000   30.360000  2.392137e+07    33.315000
# max     36.000000   36.310000   35.470000   35.830000   32.540000  5.922169e+07    35.760000

# %% [markdown]
# ##**5.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base_teste.isna().sum()
# Out:
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume         0
# media_movel    0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
base_teste.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#preenchendo os valores faltantes com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:7])
base_teste.iloc[:,0:7] = imputer.transform(base_teste.iloc[:,0:7])

# %%
#verificando novamente se ainda temos valores faltantes
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
base_teste.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %% [markdown]
# ##**5.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base_teste == 0).sum()
# Out:
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume         0
# media_movel    0
# dtype: int64

# %%
#Encontrando os valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:7])
base_teste.iloc[:,0:7] = imputer.transform(base_teste.iloc[:,0:7])

# %%
#Verificando novamente se tem valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %% [markdown]
# ##**5.4-Preparando a estrutura para teste**

# %%
#concatenando a base de dados teste com o base de treinamento
preco_real_teste = base_teste.iloc[:, 3:4].values
frames = [base, base_teste]
base_completa = pd.concat(frames)

# %%
#pegando os 90 registros anteriores para percorrer a base teste e colocando no
#no formato np.array
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)
Percorrer_teste = []
for i in range(90, 338): 
    Percorrer_teste.append(entradas[i-90:i, 0:7])
Percorrer_teste = np.array(Percorrer_teste)

# %%
#resultado da predição no formato MinMaxScaler
previsoes = regressor.predict(Percorrer_teste)

# %%
#convertendo para a escala MinMaxScaler 
normalizador_previsao = MinMaxScaler(feature_range=(0,1))
normalizador_previsao.fit_transform(base_treinamento[:,3:4])
# Out:
# array([[0.32860083],
#        [0.32426404],
#        [0.31775871],
#        ...,
#        [0.94376466],
#        [0.98967103],
#        [0.34560447]])

# %%
#colocando a previsão no formato original para preparar a visualização no gráfico
previsoes = normalizador_previsao.inverse_transform(previsoes)
previsoes
# Out:
# array([[26.072493],
#        [25.942356],
#        [26.690063],
#        [27.601889],
#        [28.238451],
#        [28.511248],
#        [28.660109],
#        [28.685179],
#        [28.628675],
#        [28.64224 ],
#        [28.677925],
#        [28.784895],
#        [28.897415],
#        [29.018425],
#        [29.0876  ],
#        [29.137892],
#        [29.188572],
#        [29.230556],
#        [29.262133],
#        [29.281033],
#        [29.287159],
#        [29.290424],
#        [29.30476 ],
#        [29.302433],
#        [29.308134],
#        [29.305798],
#        [29.283741],
#        [29.264057],
#        [29.233692],
#        [29.201681],
#        [29.183567],
#        [29.152197],
#        [29.141233],
#        [29.125937],
#        [29.097794],
#        [29.073608],
#        [29.022913],
#        [28.975323],
#        [28.896524],
#        [28.818024],
#        [28.749426],
#        [28.65862 ],
#        [28.532917],
#        [28.377487],
#        [28.24447 ],
#        [28.238329],
#        [28.351547],
#        [28.510988],
#        [28.679062],
#        [28.813383],
#        [28.9235  ],
#        [28.980042],
#        [28.960167],
#        [28.84652 ],
#        [28.599297],
#        [28.416113],
#        [28.413937],
#        [28.355099],
#        [28.52634 ],
#        [28.755518],
#        [28.944462],
#        [29.04243 ],
#        [29.074816],
#        [29.102097],
#        [29.125835],
#        [29.144978],
#        [29.157558],
#        [29.15462 ],
#        [29.131903],
#        [29.085085],
#        [29.025152],
#        [28.953873],
#        [28.88016 ],
#        [28.778606],
#        [28.674372],
#        [28.64857 ],
#        [28.72272 ],
#        [28.884674],
#        [29.006033],
#        [28.991205],
#        [29.020515],
#        [29.009325],
#        [29.041538],
#        [29.030525],
#        [28.88382 ],
#        [28.813416],
#        [28.775347],
#        [28.752459],
#        [28.667788],
#        [28.611313],
#        [28.572563],
#        [28.411732],
#        [28.288588],
#        [28.273272],
#        [28.416378],
#        [28.502766],
#        [28.50271 ],
#        [28.425055],
#        [28.367048],
#        [28.387152],
#        [28.458807],
#        [28.573698],
#        [28.681574],
#        [28.756956],
#        [28.809563],
#        [28.814432],
#        [28.835562],
#        [28.878124],
#        [28.886335],
#        [28.916212],
#        [28.943018],
#        [28.94282 ],
#        [28.938936],
#        [28.948738],
#        [28.988184],
#        [29.040909],
#        [29.10602 ],
#        [29.16585 ],
#        [29.202827],
#        [29.229584],
#        [29.247736],
#        [29.25529 ],
#        [29.260422],
#        [29.258339],
#        [29.256817],
#        [29.259111],
#        [29.266098],
#        [29.270512],
#        [29.272554],
#        [29.268806],
#        [29.223646],
#        [29.15305 ],
#        [29.087809],
#        [29.00725 ],
#        [28.925373],
#        [28.858715],
#        [28.802618],
#        [28.79167 ],
#        [28.795492],
#        [28.793194],
#        [28.707085],
#        [28.60914 ],
#        [28.458952],
#        [28.250717],
#        [28.015295],
#        [27.799015],
#        [27.57138 ],
#        [27.44901 ],
#        [27.477339],
#        [27.608664],
#        [27.72147 ],
#        [27.694313],
#        [27.663906],
#        [27.502375],
#        [27.340282],
#        [27.253862],
#        [27.136961],
#        [26.99419 ],
#        [27.113832],
#        [27.122143],
#        [27.027176],
#        [26.88242 ],
#        [26.971975],
#        [26.951664],
#        [27.235458],
#        [27.580332],
#        [27.743185],
#        [27.792414],
#        [27.896168],
#        [28.154955],
#        [28.487955],
#        [28.747606],
#        [28.847067],
#        [28.899107],
#        [28.90435 ],
#        [28.883215],
#        [28.852528],
#        [28.919706],
#        [28.998604],
#        [29.04892 ],
#        [29.087633],
#        [29.09885 ],
#        [29.07359 ],
#        [29.022654],
#        [28.952658],
#        [28.883665],
#        [28.786594],
#        [28.654194],
#        [28.416508],
#        [28.097813],
#        [27.82232 ],
#        [27.62419 ],
#        [27.508293],
#        [27.527506],
#        [27.644762],
#        [27.80374 ],
#        [27.961887],
#        [28.093727],
#        [28.216991],
#        [28.28776 ],
#        [28.217447],
#        [28.083132],
#        [28.039658],
#        [28.07999 ],
#        [28.17168 ],
#        [28.31124 ],
#        [28.511436],
#        [28.65984 ],
#        [28.757345],
#        [28.728771],
#        [28.63447 ],
#        [28.582048],
#        [28.634739],
#        [28.718622],
#        [28.827913],
#        [28.849457],
#        [28.860748],
#        [28.852346],
#        [28.83649 ],
#        [28.836954],
#        [28.834316],
#        [28.831322],
#        [28.84384 ],
#        [28.864876],
#        [28.873777],
#        [28.825163],
#        [28.74034 ],
#        [28.629253],
#        [28.498516],
#        [28.435518],
#        [28.380228],
#        [28.39818 ],
#        [28.478455],
#        [28.531435],
#        [28.569704],
#        [28.594114],
#        [28.59828 ],
#        [28.66709 ],
#        [28.782814],
#        [28.816479],
#        [28.873774],
#        [28.963913],
#        [29.035048],
#        [29.069517],
#        [29.091745],
#        [29.124777],
#        [29.154917],
#        [29.17758 ]], dtype=float32)

# %% [markdown]
# #**6-Análise dos resuldatos**

# %%
#Visualizando o gráfico da Previsão da rede
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão do preço das ações')
plt.xlabel('Tempo em dias')
plt.ylabel('Preço das ações')
plt.legend()
plt.show()

# %%
#estatísticas do preço real comparado com a previsão
df1 = pd.DataFrame(preco_real_teste).T
df2 = pd.DataFrame(previsoes).T

df3 = pd.concat([df1,df2]).T
df3.columns = ['Preco real', 'Previsoes']
df3.describe()
# Out:
#        Preco real   Previsoes
# count  247.000000  248.000000
# mean    32.114413   28.611514
# std      1.574197    0.610448
# min     28.760000   25.942356
# 25%     30.940000   28.415569
# 50%     31.960000   28.794343
# 75%     33.220000   29.023473
# max     35.830000   29.308134

# %%
#df2 = pd.DataFrame(previsoes)
#df2.describe()

# %%
#df1 = pd.DataFrame(preco_real_teste)
#df1.describe()
