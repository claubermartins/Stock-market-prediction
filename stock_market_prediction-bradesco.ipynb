# %% [markdown]
# <a href="https://colab.research.google.com/github/claubermartins/Stock-market-prediction/blob/main/stock_market_prediction-bradesco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install inflection
# Out:
# Collecting inflection
#   Downloading https://files.pythonhosted.org/packages/59/91/aa6bde563e0085a02a435aa99b49ef75b0a4b062635e606dab23ce18d720/inflection-0.5.1-py2.py3-none-any.whl
# Installing collected packages: inflection
# Successfully installed inflection-0.5.1

# %% [markdown]
# #**1-Importando bibliotecas**

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import seaborn as sns
import datetime
import inflection
from IPython.core.display import HTML

# %% [markdown]
# #**2-Funções auxiliares para o Jupyter Notebook**

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #**2.1Método de importação de arquivos do Google Colab**

# %%
from google.colab import files
upload = files.upload()
print("downloaded files: ")
print(*upload, sep = "\n")
# Out:
#      <input type="file" id="files-c1c2f9f0-9ec0-4ce7-8d56-8043522efda3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1c2f9f0-9ec0-4ce7-8d56-8043522efda3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BBDC4-teste.csv to BBDC4-teste.csv
# Saving BBDC4-treinamento.csv to BBDC4-treinamento.csv
# downloaded files:
# BBDC4-teste.csv
# BBDC4-treinamento.csv

# %% [markdown]
# #**3-Tratamento dos dados**

# %% [markdown]
# ##**3.1-Importando os dados**

# %%
base = pd.read_csv('BBDC4-treinamento.csv')
base = base.drop('Date', axis = 1)

# %%
#valores estatísticos
base.describe()
# Out:
#               Open         High          Low        Close    Adj Close        Volume
# count  2231.000000  2231.000000  2231.000000  2231.000000  2231.000000  2.231000e+03
# mean     16.521398    16.723608    16.310453    16.525766    12.619423  1.526746e+07
# std       4.126155     4.177349     4.065883     4.128200     4.450117  8.569623e+06
# min       9.687407     9.858160     9.636181     9.681715     7.250297  0.000000e+00
# 25%      13.323936    13.466231    13.311944    13.311944     9.156341  1.052012e+07
# 50%      15.382032    15.579269    15.182819    15.358316    10.968378  1.437028e+07
# 75%      18.417855    18.663911    18.153644    18.472953    14.902138  1.914296e+07
# max      29.545454    29.719696    29.106060    29.484848    26.372849  8.762744e+07

# %%
base.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %% [markdown]
# ##**3.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
#       Open  High  Low  Close  Adj Close  Volume
# 2015   NaN   NaN  NaN    NaN        NaN     NaN

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# #**3.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base == 0).sum()
# Out:
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume       135
# dtype: int64

# %%
#Encontrando os valores nulos
base.loc[base['Volume'] == 0]
# Out:
#            Open       High        Low      Close  Adj Close  Volume
# 34    13.311944  13.311944  13.311944  13.311944   8.555276     0.0
# 35    13.311944  13.311944  13.311944  13.311944   8.555276     0.0
# 36    13.311944  13.311944  13.311944  13.311944   8.555276     0.0
# 37    13.311944  13.311944  13.311944  13.311944   8.555276     0.0
# 38    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 39    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 40    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 41    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 42    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 43    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 44    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 45    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 46    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 47    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 48    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 49    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 50    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 51    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 52    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 53    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 54    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 55    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 56    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 57    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 58    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 59    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 60    13.311944  13.311944  13.311944  13.311944   8.559290     0.0
# 61    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 62    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 63    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 64    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 65    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 66    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 67    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 68    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 69    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 70    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 71    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 72    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 73    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 74    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 75    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 76    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 77    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 78    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 79    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 80    13.311944  13.311944  13.311944  13.311944   8.563306     0.0
# 81    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 82    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 83    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 84    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 85    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 86    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 87    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 88    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 89    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 90    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 91    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 92    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 93    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 94    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 95    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 96    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 97    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 98    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 99    13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 100   13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 101   13.311944  13.311944  13.311944  13.311944   8.567323     0.0
# 102   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 103   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 104   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 105   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 106   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 107   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 108   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 109   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 110   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 111   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 112   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 113   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 114   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 115   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 116   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 117   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 118   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 119   13.311944  13.311944  13.311944  13.311944   8.571342     0.0
# 120   13.311944  13.311944  13.311944  13.311944   8.611738     0.0
# 121   13.311944  13.311944  13.311944  13.311944   8.611738     0.0
# 122   13.311944  13.311944  13.311944  13.311944   8.611738     0.0
# 123   13.311944  13.311944  13.311944  13.311944   8.615780     0.0
# 124   13.311944  13.311944  13.311944  13.311944   8.615780     0.0
# 125   13.311944  13.311944  13.311944  13.311944   8.615780     0.0
# 126   13.311944  13.311944  13.311944  13.311944   8.615780     0.0
# 127   13.311944  13.311944  13.311944  13.311944   8.615780     0.0
# 275   12.849621  12.849621  12.849621  12.849621   8.456571     0.0
# 276   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 277   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 278   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 279   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 280   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 281   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 282   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 283   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 284   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 285   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 286   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 287   12.849621  12.849621  12.849621  12.849621   8.481547     0.0
# 288   12.849621  12.849621  12.849621  12.849621   8.485688     0.0
# 289   12.849621  12.849621  12.849621  12.849621   8.485688     0.0
# 290   12.849621  12.849621  12.849621  12.849621   8.485688     0.0
# 291   12.849621  12.849621  12.849621  12.849621   8.485688     0.0
# 308   13.992289  13.992289  13.992289  13.992289   9.240288     0.0
# 310   14.315686  14.315686  14.315686  14.315686   9.458089     0.0
# 333   13.453295  13.453295  13.453295  13.453295   8.892475     0.0
# 337   13.259257  13.259257  13.259257  13.259257   8.764221     0.0
# 450   13.173018  13.173018  13.173018  13.173018   8.778509     0.0
# 451   13.173018  13.173018  13.173018  13.173018   8.778509     0.0
# 452   13.173018  13.173018  13.173018  13.173018   8.778509     0.0
# 461   13.237697  13.237697  13.237697  13.237697   8.826204     0.0
# 482   13.466231  13.466231  13.466231  13.466231   8.983266     0.0
# 507   13.561094  13.561094  13.561094  13.561094   9.238768     0.0
# 799   15.808915  15.808915  15.808915  15.808915  11.126439     0.0
# 819   15.291912  15.291912  15.291912  15.291912  10.768173     0.0
# 881   13.674498  13.674498  13.674498  13.674498   9.718309     0.0
# 1831  19.207989  19.207989  19.207989  19.207989  16.143587     0.0
# 1844  18.691460  18.691460  18.691460  18.691460  15.720361     0.0
# 1904  23.601929  23.601929  23.601929  23.601929  20.021959     0.0
# 1929  25.413223  25.413223  25.413223  25.413223  21.570072     0.0
# 1944  23.140495  23.140495  23.140495  23.140495  19.641043     0.0
# 1946  23.360882  23.360882  23.360882  23.360882  19.839302     0.0
# 1953  22.176308  22.176308  22.176308  22.176308  18.833303     0.0
# 1956  23.154268  23.154268  23.154268  23.154268  19.663834     0.0
# 1981  23.464188  23.464188  23.464188  23.464188  19.938654     0.0
# 1985  23.312672  23.312672  23.312672  23.312672  20.304495     0.0
# 2003  27.410467  27.410467  27.410467  27.410467  23.886627     0.0

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:6])
base.iloc[:,0:6] = imputer.transform(base.iloc[:,0:6])

# %%
#Verificando novamente se ainda temos valores nulos
base.loc[base['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
#base = base.dropna()

# %%
#base.sample()

# %% [markdown]
# #**-Descrição dos dados** IGNORE ESTA CÉLULA

# %%
#Tendencia central - mean, median
ct1 = pd.DataFrame(base.apply(np.mean)).T #T transpondo 
ct2 = pd.DataFrame(base.apply(np.median)).T
#Dispersão - std(desvio padrão), min, max, range
d1 = pd.DataFrame(base.apply(np.std)).T
d2 = pd.DataFrame(base.apply(min)).T
d3 = pd.DataFrame(base.apply(max)).T
d4 = pd.DataFrame(base.apply(lambda x: x.max() - x.min())).T
#concatenate
m = pd.concat([d2,d3,d4,ct1,ct2,d1]).T.reset_index()
m.columns = ['attributes','min','max','range', 'mean', 'median', 'std']
m

# %%
base.shape[0]
# Out:
# 2478

# %% [markdown]
# #**4-Treinamento da rede**

# %%
#normalizando a base de dados com o MinMaxScaler
base_treinamento = base.iloc[:, 0:6].values
normalizador = MinMaxScaler(feature_range=(0,1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
#Comparando a predição com o preço real
previsores = []
preco_real = []
for i in range(90, 2232):
    previsores.append(base_treinamento_normalizada[i-90:i, 0:6])
    preco_real.append(base_treinamento_normalizada[i, 3:4])
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %%
#estrutura da rede neural 
regressor = Sequential()
regressor.add(LSTM(units = 128, return_sequences = True, input_shape = (previsores.shape[1], 6)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'sigmoid'))

es = EarlyStopping(monitor = 'loss', min_delta = 1e-15, patience = 20, verbose = 1)

#regressor.compile(optimizer = 'RMSprop', loss = 'mean_squared_error',
#                  metrics = ['mean_absolute_error'])
opt = tf.keras.optimizers.Adam(amsgrad=True)
regressor.compile(optimizer = opt, loss = 'mean_squared_error',
                  metrics = ['mean_absolute_error'])
#opt = tf.keras.optimizers.RMSprop(centered=True)
#regressor.compile(optimizer = opt, loss = 'mean_squared_error',
#                 metrics = ['mean_absolute_error'])

regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32,
              callbacks = [es])
#regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32)
# Out:
# Epoch 1/600
# 67/67 [==============================] - 37s 18ms/step - loss: 0.0268 - mean_absolute_error: 0.1255
# Epoch 2/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0046 - mean_absolute_error: 0.0521
# Epoch 3/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0474
# Epoch 4/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0032 - mean_absolute_error: 0.0430
# Epoch 5/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0033 - mean_absolute_error: 0.0422
# Epoch 6/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0027 - mean_absolute_error: 0.0385
# Epoch 7/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0026 - mean_absolute_error: 0.0393
# Epoch 8/600
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0023 - mean_absolute_error: 0.0367
# Epoch 9/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0388
# Epoch 10/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0352
# Epoch 11/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0021 - mean_absolute_error: 0.0348
# Epoch 12/600
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0021 - mean_absolute_error: 0.0345
# Epoch 13/600
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0350
# Epoch 14/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0020 - mean_absolute_error: 0.0336
# Epoch 15/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0311
# Epoch 16/600
# 67/67 [==============================] - 1s 16ms/step - loss: 0.0019 - mean_absolute_error: 0.0331
# Epoch 17/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0320
# Epoch 18/600
# 67/67 [==============================] - 1s 20ms/step - loss: 0.0014 - mean_absolute_error: 0.0292
# Epoch 19/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0326
# Epoch 20/600
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0015 - mean_absolute_error: 0.0294
# Epoch 21/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0301
# Epoch 22/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0287
# Epoch 23/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0016 - mean_absolute_error: 0.0302
# Epoch 24/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0307
# Epoch 25/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0293
# Epoch 26/600
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0014 - mean_absolute_error: 0.0279
# Epoch 27/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0273
# Epoch 28/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0271
# Epoch 29/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0284
# Epoch 30/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0276
# Epoch 31/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0265
# Epoch 32/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0278
# Epoch 33/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0264
# Epoch 34/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0277
# Epoch 35/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0275
# Epoch 36/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0272
# Epoch 37/600
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0262
# Epoch 38/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0256
# Epoch 39/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0259
# Epoch 40/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0251
# Epoch 41/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0256
# Epoch 42/600
# 67/67 [==============================] - 1s 17ms/step - loss: 9.7675e-04 - mean_absolute_error: 0.0238
# Epoch 43/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0261
# Epoch 44/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0251
# Epoch 45/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0242
# Epoch 46/600
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0011 - mean_absolute_error: 0.0241
# Epoch 47/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0254
# Epoch 48/600
# 67/67 [==============================] - 1s 20ms/step - loss: 9.9302e-04 - mean_absolute_error: 0.0241
# Epoch 49/600
# 67/67 [==============================] - 1s 21ms/step - loss: 9.6525e-04 - mean_absolute_error: 0.0238
# Epoch 50/600
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0015 - mean_absolute_error: 0.0255
# Epoch 51/600
# 67/67 [==============================] - 1s 19ms/step - loss: 9.6258e-04 - mean_absolute_error: 0.0238
# Epoch 52/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0240
# Epoch 53/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0241
# Epoch 54/600
# 67/67 [==============================] - 1s 17ms/step - loss: 8.8698e-04 - mean_absolute_error: 0.0230
# Epoch 55/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0259
# Epoch 56/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0247
# Epoch 57/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0233
# Epoch 58/600
# 67/67 [==============================] - 1s 18ms/step - loss: 9.9267e-04 - mean_absolute_error: 0.0229
# Epoch 59/600
# 67/67 [==============================] - 1s 17ms/step - loss: 9.4090e-04 - mean_absolute_error: 0.0230
# Epoch 60/600
# 67/67 [==============================] - 1s 20ms/step - loss: 9.2466e-04 - mean_absolute_error: 0.0231
# Epoch 61/600
# 67/67 [==============================] - 1s 19ms/step - loss: 9.7648e-04 - mean_absolute_error: 0.0233
# Epoch 62/600
# 67/67 [==============================] - 1s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0239
# Epoch 63/600
# 67/67 [==============================] - 1s 19ms/step - loss: 0.0010 - mean_absolute_error: 0.0243
# Epoch 64/600
# 67/67 [==============================] - 1s 17ms/step - loss: 8.7946e-04 - mean_absolute_error: 0.0227
# Epoch 65/600
# 67/67 [==============================] - 1s 21ms/step - loss: 0.0011 - mean_absolute_error: 0.0235
# Epoch 66/600
# 67/67 [==============================] - 1s 20ms/step - loss: 8.7908e-04 - mean_absolute_error: 0.0227
# Epoch 67/600
# 67/67 [==============================] - 1s 18ms/step - loss: 9.3942e-04 - mean_absolute_error: 0.0229
# Epoch 68/600
# 67/67 [==============================] - 1s 19ms/step - loss: 8.6709e-04 - mean_absolute_error: 0.0213
# Epoch 69/600
# 67/67 [==============================] - 1s 17ms/step - loss: 8.2803e-04 - mean_absolute_error: 0.0217
# Epoch 70/600
# 67/67 [==============================] - 1s 19ms/step - loss: 8.9633e-04 - mean_absolute_error: 0.0226
# Epoch 71/600
# 67/67 [==============================] - 1s 17ms/step - loss: 9.3071e-04 - mean_absolute_error: 0.0230
# Epoch 72/600
# 67/67 [==============================] - 1s 18ms/step - loss: 0.
# Epoch 235/600
# 67/67 [==============================] - 1s 19ms/step - loss: 9.3635e-04 - mean_absolute_error: 0.0191
# Epoch 00235: early stopping

# %% [markdown]
# #**5-Teste da rede**

# %% [markdown]
# ##**5.1-Importando os dados para teste**

# %%
#criando a base de dados teste
base_teste = pd.read_csv('BBDC4-teste.csv')
base_teste = base_teste.drop('Date', axis = 1)

# %%
#valores estatísticos
base_teste.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  247.000000  247.000000  247.000000  247.000000  247.000000  2.470000e+02
# mean    32.119408   32.470714   31.702913   32.114507   29.294712  2.005127e+07
# std      1.582360    1.564653    1.546998    1.574365    1.421719  7.561476e+06
# min     28.836363   29.236362   28.509090   28.763636   26.142099  8.201050e+06
# 25%     30.854546   31.227272   30.536362   30.936363   28.326915  1.476304e+07
# 50%     31.916666   32.281818   31.563637   31.962120   29.204481  1.841323e+07
# 75%     33.359848   33.734091   32.804544   33.222727   30.359981  2.392137e+07
# max     36.000000   36.309090   35.472729   35.827271   32.543896  5.922169e+07

# %% [markdown]
# ##**5.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base_teste.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
#     Open  High  Low  Close  Adj Close  Volume
# 42   NaN   NaN  NaN    NaN        NaN     NaN

# %%
#preenchendo os valores faltantes com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#verificando novamente se ainda temos valores faltantes
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# #**5.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base_teste == 0).sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Encontrando os valores nulos
base_teste.loc[base_teste['Volume'] == 0]

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:6])
base_teste.iloc[:,0:6] = imputer.transform(base_teste.iloc[:,0:6])

# %%
#Verificando novamente se tem valores nulos
base_teste.loc[base_teste['Volume'] == 0]

# %% [markdown]
# ##**5.4-Preparando a estrutura para teste**

# %%
#concatenando a base de dados teste com o base de treinamento
preco_real_teste = base_teste.iloc[:, 3:4].values
frames = [base, base_teste]
base_completa = pd.concat(frames)

# %%
#pegando os 90 registros anteriores para percorrer a base teste e colocando no
#no formato np.array
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)
Percorrer_teste = []
for i in range(90, 338): 
    Percorrer_teste.append(entradas[i-90:i, 0:6])
Percorrer_teste = np.array(Percorrer_teste)

# %%
#resultado da predição no formato MinMaxScaler
previsoes = regressor.predict(Percorrer_teste)

# %%
#convertendo para a escala MinMaxScaler 
normalizador_previsao = MinMaxScaler(feature_range=(0,1))
normalizador_previsao.fit_transform(base_treinamento[:,3:4])
# Out:
# array([[0.32860083],
#        [0.32426404],
#        [0.31775871],
#        ...,
#        [0.91124758],
#        [0.94376466],
#        [0.98967103]])

# %%
#colocando a previsão no formato original para preparar a visualização no gráfico
previsoes = normalizador_previsao.inverse_transform(previsoes)
previsoes
# Out:
# array([[28.70347 ],
#        [28.738523],
#        [28.765425],
#        [28.788193],
#        [28.806517],
#        [28.820595],
#        [28.83346 ],
#        [28.842613],
#        [28.849678],
#        [28.855629],
#        [28.860006],
#        [28.863842],
#        [28.866892],
#        [28.870384],
#        [28.87205 ],
#        [28.87402 ],
#        [28.875755],
#        [28.877872],
#        [28.879509],
#        [28.880896],
#        [28.881554],
#        [28.883997],
#        [28.88429 ],
#        [28.88583 ],
#        [28.886166],
#        [28.886187],
#        [28.88656 ],
#        [28.886852],
#        [28.887003],
#        [28.887682],
#        [28.88752 ],
#        [28.888323],
#        [28.888285],
#        [28.888441],
#        [28.888807],
#        [28.888536],
#        [28.8886  ],
#        [28.888529],
#        [28.888334],
#        [28.888222],
#        [28.887934],
#        [28.887375],
#        [28.886812],
#        [28.886322],
#        [28.885742],
#        [28.88574 ],
#        [28.886711],
#        [28.887136],
#        [28.887936],
#        [28.888262],
#        [28.88892 ],
#        [28.889196],
#        [28.889362],
#        [28.889194],
#        [28.888906],
#        [28.887854],
#        [28.887535],
#        [28.88661 ],
#        [28.884428],
#        [28.884487],
#        [28.884195],
#        [28.884886],
#        [28.884092],
#        [28.884258],
#        [28.88459 ],
#        [28.885382],
#        [28.885826],
#        [28.886234],
#        [28.886442],
#        [28.886318],
#        [28.886168],
#        [28.88599 ],
#        [28.885786],
#        [28.884842],
#        [28.884953],
#        [28.884628],
#        [28.885508],
#        [28.88531 ],
#        [28.886066],
#        [28.886263],
#        [28.88655 ],
#        [28.886532],
#        [28.886814],
#        [28.887098],
#        [28.88678 ],
#        [28.886456],
#        [28.886845],
#        [28.886135],
#        [28.88598 ],
#        [28.88427 ],
#        [28.883696],
#        [28.880566],
#        [28.878191],
#        [28.873966],
#        [28.873705],
#        [28.875074],
#        [28.875807],
#        [28.876213],
#        [28.87663 ],
#        [28.878008],
#        [28.879658],
#        [28.8818  ],
#        [28.883682],
#        [28.885149],
#        [28.886326],
#        [28.887356],
#        [28.887846],
#        [28.888721],
#        [28.889078],
#        [28.889307],
#        [28.889626],
#        [28.889666],
#        [28.889605],
#        [28.889599],
#        [28.889496],
#        [28.889534],
#        [28.889536],
#        [28.889992],
#        [28.89016 ],
#        [28.890308],
#        [28.890566],
#        [28.890623],
#        [28.890825],
#        [28.890873],
#        [28.890991],
#        [28.891203],
#        [28.891571],
#        [28.89173 ],
#        [28.891953],
#        [28.892056],
#        [28.892073],
#        [28.892076],
#        [28.892044],
#        [28.892036],
#        [28.891975],
#        [28.892145],
#        [28.891867],
#        [28.892134],
#        [28.891977],
#        [28.892307],
#        [28.891438],
#        [28.89171 ],
#        [28.890936],
#        [28.890562],
#        [28.889235],
#        [28.888613],
#        [28.886671],
#        [28.884518],
#        [28.882143],
#        [28.880806],
#        [28.879974],
#        [28.878302],
#        [28.874855],
#        [28.874437],
#        [28.869987],
#        [28.868345],
#        [28.86556 ],
#        [28.862232],
#        [28.856125],
#        [28.856201],
#        [28.850315],
#        [28.842573],
#        [28.829926],
#        [28.824463],
#        [28.809881],
#        [28.812595],
#        [28.813051],
#        [28.81682 ],
#        [28.810762],
#        [28.816076],
#        [28.823915],
#        [28.836807],
#        [28.84772 ],
#        [28.854837],
#        [28.860971],
#        [28.864866],
#        [28.86759 ],
#        [28.868628],
#        [28.870869],
#        [28.871868],
#        [28.872782],
#        [28.873512],
#        [28.87399 ],
#        [28.87376 ],
#        [28.873724],
#        [28.874699],
#        [28.875217],
#        [28.875393],
#        [28.874634],
#        [28.870235],
#        [28.865887],
#        [28.859804],
#        [28.85456 ],
#        [28.84744 ],
#        [28.847622],
#        [28.847988],
#        [28.852913],
#        [28.857397],
#        [28.863066],
#        [28.868206],
#        [28.871943],
#        [28.873331],
#        [28.87545 ],
#        [28.877436],
#        [28.879538],
#        [28.880795],
#        [28.882374],
#        [28.88393 ],
#        [28.884905],
#        [28.88579 ],
#        [28.885422],
#        [28.885868],
#        [28.88545 ],
#        [28.88573 ],
#        [28.88529 ],
#        [28.885519],
#        [28.88405 ],
#        [28.883804],
#        [28.881794],
#        [28.880348],
#        [28.877127],
#        [28.874798],
#        [28.870382],
#        [28.868351],
#        [28.866737],
#        [28.866123],
#        [28.861032],
#        [28.86192 ],
#        [28.857407],
#        [28.8581  ],
#        [28.856676],
#        [28.858635],
#        [28.86177 ],
#        [28.865479],
#        [28.867533],
#        [28.870306],
#        [28.872135],
#        [28.87379 ],
#        [28.87541 ],
#        [28.877058],
#        [28.877497],
#        [28.879044],
#        [28.88033 ],
#        [28.882105],
#        [28.882593],
#        [28.883686],
#        [28.884491],
#        [28.88528 ]], dtype=float32)

# %% [markdown]
# ##**6-Análise dos resuldatos**

# %%
#Visualizando o gráfico da Previsão da rede
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão do preço das ações')
plt.xlabel('Tempo em dias')
plt.ylabel('Preço das ações')
plt.legend()
plt.show()

# %%
#estatísticas do preço real comparado com a previsão
df1 = pd.DataFrame(preco_real_teste).T
df2 = pd.DataFrame(previsoes).T

df3 = pd.concat([df1,df2]).T
df3.columns = ['Preco real', 'Previsoes']
df3.describe()
# Out:
#        Preco real   Previsoes
# count  248.000000  248.000000
# mean    32.114507   28.874349
# std      1.571175    0.024112
# min     28.763636   28.703470
# 25%     30.936363   28.870384
# 50%     31.967424   28.884024
# 75%     33.202271   28.887361
# max     35.827271   28.892307

# %%
#df2 = pd.DataFrame(previsoes)
#df2.describe()

# %%
#df1 = pd.DataFrame(preco_real_teste)
#df1.describe()
