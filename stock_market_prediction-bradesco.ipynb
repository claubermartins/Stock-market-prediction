# %% [markdown]
# <a href="https://colab.research.google.com/github/claubermartins/Stock-market-prediction/blob/main/stock_market_prediction-bradesco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install inflection
# Out:
# Requirement already satisfied: inflection in /usr/local/lib/python3.7/dist-packages (0.5.1)

# %% [markdown]
# #**1-Importando bibliotecas**

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import EarlyStopping 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import seaborn as sns
import datetime
import inflection
from IPython.core.display import HTML

# %% [markdown]
# #**2-Funções auxiliares para o Jupyter Notebook**

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ##**2.1Método de importação de arquivos do Google Colab**

# %%
from google.colab import files
upload = files.upload()
print("downloaded files: ")
print(*upload, sep = "\n")
# Out:
#      <input type="file" id="files-fd987579-0f6c-4617-9b54-3365a26ca718" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd987579-0f6c-4617-9b54-3365a26ca718">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BBDC4-teste.csv to BBDC4-teste.csv
# Saving BBDC4-treinamento.csv to BBDC4-treinamento.csv
# downloaded files:
# BBDC4-teste.csv
# BBDC4-treinamento.csv

# %% [markdown]
# #**3-Tratamento dos dados**

# %% [markdown]
# ##**3.1-Importando os dados**

# %%
base = pd.read_csv('BBDC4-treinamento.csv')
base = base.drop('Date', axis = 1)

# %%
#valores estatísticos
base.describe()
# Out:
#               Open         High          Low        Close    Adj Close        Volume  media_movel
# count  2231.000000  2231.000000  2231.000000  2231.000000  2231.000000  2.231000e+03  2232.000000
# mean     16.521398    16.723608    16.310453    16.525766    12.619423  1.526746e+07    16.521145
# std       4.126155     4.177349     4.065883     4.128200     4.450117  8.569623e+06     4.118673
# min       9.687407     9.858160     9.636181     9.681715     7.250297  0.000000e+00     9.738633
# 25%      13.323936    13.466231    13.311944    13.311944     9.156341  1.052012e+07    13.312314
# 50%      15.382032    15.579269    15.182819    15.358316    10.968378  1.437028e+07    15.377289
# 75%      18.417855    18.663911    18.153644    18.472953    14.902138  1.914296e+07    18.439038
# max      29.545454    29.719696    29.106060    29.484848    26.372849  8.762744e+07    29.204545

# %%
base.dtypes
# Out:
# Open           float64
# High           float64
# Low            float64
# Close          float64
# Adj Close      float64
# Volume         float64
# media_movel    float64
# dtype: object

# %% [markdown]
# ##**3.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base.isna().sum()
# Out:
# Open           1
# High           1
# Low            1
# Close          1
# Adj Close      1
# Volume         1
# media_movel    0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
base.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:7])
base.iloc[:,0:7] = imputer.transform(base.iloc[:,0:7])

# %%
#verificando novamente se ainda temos valores faltantes
base.loc[pd.isnull(base['Open'])]
base.loc[pd.isnull(base['High'])]
base.loc[pd.isnull(base['Low'])]
base.loc[pd.isnull(base['Close'])]
base.loc[pd.isnull(base['Adj Close'])]
base.loc[pd.isnull(base['Volume'])]
base.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Vol
# 285   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 286   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 287   12.849621  12.849621  12.849621  12.849621   8.481547     0.0    12.849621
# 288   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 289   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 290   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 291   12.849621  12.849621  12.849621  12.849621   8.485688     0.0    12.849621
# 308   13.992289  13.992289  13.992289  13.992289   9.240288     0.0    13.753694
# 310   14.315686  14.315686  14.315686  14.315686   9.458089     0.0    14.258193
# 333   13.453295  13.453295  13.453295  13.453295   8.892475     0.0    13.410175
# 337   13.259257  13.259257  13.259257  13.259257   8.764221     0.0    13.437484
# 450   13.173018  13.173018  13.173018  13.173018   8.778509     0.0    12.908551
# 451   13.173018  13.173018  13.173018  13.173018   8.778509     0.0    13.093965
# 452   13.173018  13.173018  13.173018  13.173018   8.778509     0.0    13.173018
# 461   13.237697  13.237697  13.237697  13.237697   8.826204     0.0    13.270755
# 482   13.466231  13.466231  13.466231  13.466231   8.983266     0.0    13.438922
# 507   13.561094  13.561094  13.561094  13.561094   9.238768     0.0    13.592715
# 799   15.808915  15.808915  15.808915  15.808915  11.126439     0.0    15.491124
# 819   15.291912  15.291912  15.291912  15.291912  10.768173     0.0    15.459503
# 881   13.674498  13.674498  13.674498  13.674498   9.718309     0.0    13.663431
# 1831  19.207989  19.207989  19.207989  19.207989  16.143587     0.0    19.065656
# 1844  18.691460  18.691460  18.691460  18.691460  15.720361     0.0    18.388429
# 1904  23.601929  23.601929  23.601929  23.601929  20.021959     0.0    23.666208
# 1929  25.413223  25.413223  25.413223  25.413223  21.570072     0.0    25.376491
# 1944  23.140495  23.140495  23.140495  23.140495  19.641043     0.0    23.790174
# 1946  23.360882  23.360882  23.360882  23.360882  19.839302     0.0    23.236914
# 1953  22.176308  22.176308  22.176308  22.176308  18.833303     0.0    22.497703
# 1956  23.154268  23.154268  23.154268  23.154268  19.663834     0.0    22.695132
# 1981  23.464188  23.464188  23.464188  23.464188  19.938654     0.0    23.172635
# 1985  23.312672  23.312672  23.312672  23.312672  20.304495     0.0    23.147383
# 2003  27.410467  27.410467  27.410467  27.410467  23.886627     0.0    26.478420

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base.iloc[:,0:7])
base.iloc[:,0:7] = imputer.transform(base.iloc[:,0:7])

# %%
#Verificando novamente se ainda temos valores nulos
base.loc[base['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#base = base.dropna()

# %%
#base.sample()

# %% [markdown]
# #**-Descrição dos dados** IGNORE ESTA CÉLULA

# %%
#Tendencia central - mean, median
ct1 = pd.DataFrame(base.apply(np.mean)).T #T transpondo 
ct2 = pd.DataFrame(base.apply(np.median)).T
#Dispersão - std(desvio padrão), min, max, range
d1 = pd.DataFrame(base.apply(np.std)).T
d2 = pd.DataFrame(base.apply(min)).T
d3 = pd.DataFrame(base.apply(max)).T
d4 = pd.DataFrame(base.apply(lambda x: x.max() - x.min())).T
#concatenate
m = pd.concat([d2,d3,d4,ct1,ct2,d1]).T.reset_index()
m.columns = ['attributes','min','max','range', 'mean', 'median', 'std']
m

# %%
base.shape[0]
# Out:
# 2478

# %% [markdown]
# #**4-Treinamento da rede**

# %%
#normalizando a base de dados com o MinMaxScaler
base_treinamento = base.iloc[:, 0:7].values
normalizador = MinMaxScaler(feature_range=(0,1))
base_treinamento_normalizada = normalizador.fit_transform(base_treinamento)

# %%
#Comparando a predição com o preço real
previsores = []
preco_real = []
for i in range(90, 2232):
    previsores.append(base_treinamento_normalizada[i-90:i, 0:7])
    preco_real.append(base_treinamento_normalizada[i, 3:4])
previsores, preco_real = np.array(previsores), np.array(preco_real)

# %%
#estrutura da rede neural 
regressor = Sequential()
regressor.add(LSTM(units = 90, return_sequences = True, input_shape = (previsores.shape[1], 7)))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 90, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 90, return_sequences = True))
regressor.add(Dropout(0.3))

regressor.add(LSTM(units = 90))
regressor.add(Dropout(0.3))

regressor.add(Dense(units = 1, activation = 'sigmoid'))

es = EarlyStopping(monitor = 'loss', min_delta = 1e-15, patience = 20, verbose = 1)

#regressor.compile(optimizer = 'RMSprop', loss = 'mean_squared_error',
#                  metrics = ['mean_absolute_error'])
opt = tf.keras.optimizers.Adam(amsgrad=True)
regressor.compile(optimizer = opt, loss = 'mean_squared_error',
                  metrics = ['mean_absolute_error'])
#opt = tf.keras.optimizers.RMSprop(centered=True)
#regressor.compile(optimizer = opt, loss = 'mean_squared_error',
#                 metrics = ['mean_absolute_error'])

regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32,
              callbacks = [es])
#regressor.fit(previsores, preco_real, epochs = 600, batch_size = 32)
# Out:
# Epoch 1/600
# 67/67 [==============================] - 13s 98ms/step - loss: 0.0114 - mean_absolute_error: 0.0780
# Epoch 2/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0038 - mean_absolute_error: 0.0465
# Epoch 3/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0029 - mean_absolute_error: 0.0406
# Epoch 4/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0026 - mean_absolute_error: 0.0388
# Epoch 5/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0028 - mean_absolute_error: 0.0398
# Epoch 6/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0024 - mean_absolute_error: 0.0372
# Epoch 7/600
# 67/67 [==============================] - 6s 97ms/step - loss: 0.0023 - mean_absolute_error: 0.0358
# Epoch 8/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0020 - mean_absolute_error: 0.0338
# Epoch 9/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0022 - mean_absolute_error: 0.0350
# Epoch 10/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0019 - mean_absolute_error: 0.0328
# Epoch 11/600
# 67/67 [==============================] - 6s 97ms/step - loss: 0.0019 - mean_absolute_error: 0.0321
# Epoch 12/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0018 - mean_absolute_error: 0.0315
# Epoch 13/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0017 - mean_absolute_error: 0.0307
# Epoch 14/600
# 67/67 [==============================] - 7s 97ms/step - loss: 0.0017 - mean_absolute_error: 0.0302
# Epoch 15/600
# 67/67 [==============================] - 7s 99ms/step - loss: 0.0016 - mean_absolute_error: 0.0293
# Epoch 16/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0015 - mean_absolute_error: 0.0281
# Epoch 17/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0014 - mean_absolute_error: 0.0275
# Epoch 18/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0015 - mean_absolute_error: 0.0291
# Epoch 19/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.0014 - mean_absolute_error: 0.0272
# Epoch 20/600
# 67/67 [==============================] - 7s 98ms/step - loss: 0.
600
# 67/67 [==============================] - 7s 98ms/step - loss: 8.0879e-04 - mean_absolute_error: 0.0199
# Epoch 126/600
# 67/67 [==============================] - 7s 98ms/step - loss: 8.1143e-04 - mean_absolute_error: 0.0199
# Epoch 00126: early stopping

# %% [markdown]
# #**5-Teste da rede**

# %% [markdown]
# ##**5.1-Importando os dados para teste**

# %%
#criando a base de dados teste
base_teste = pd.read_csv('BBDC4-teste.csv')
base_teste = base_teste.drop('Date', axis = 1)

# %%
#valores estatísticos
base_teste.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume  media_movel
# count  247.000000  247.000000  247.000000  247.000000  247.000000  2.470000e+02   248.000000
# mean    32.119312   32.470891   31.703077   32.114413   29.294737  2.005127e+07    32.113508
# std      1.582138    1.564298    1.546993    1.574197    1.422042  7.561476e+06     1.542148
# min     28.840000   29.240000   28.510000   28.760000   26.140000  8.201050e+06    29.000000
# 25%     30.850000   31.230000   30.535000   30.940000   28.325000  1.476304e+07    30.930000
# 50%     31.920000   32.280000   31.560000   31.960000   29.200000  1.841323e+07    31.920000
# 75%     33.360000   33.735000   32.805000   33.220000   30.360000  2.392137e+07    33.292500
# max     36.000000   36.310000   35.470000   35.830000   32.540000  5.922169e+07    35.760000

# %% [markdown]
# ##**5.2-Tratando os Valores Faltantes**

# %%
#valores faltantes
base_teste.isna().sum()
# Out:
# Open           1
# High           1
# Low            1
# Close          1
# Adj Close      1
# Volume         1
# media_movel    0
# dtype: int64

# %%
#encontrando onde os valores faltantes estão
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
base_teste.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#preenchendo os valores faltantes com o valor médio
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:7])
base_teste.iloc[:,0:7] = imputer.transform(base_teste.iloc[:,0:7])

# %%
#verificando novamente se ainda temos valores faltantes
base_teste.loc[pd.isnull(base_teste['Open'])]
base_teste.loc[pd.isnull(base_teste['High'])]
base_teste.loc[pd.isnull(base_teste['Low'])]
base_teste.loc[pd.isnull(base_teste['Close'])]
base_teste.loc[pd.isnull(base_teste['Adj Close'])]
base_teste.loc[pd.isnull(base_teste['Volume'])]
base_teste.loc[pd.isnull(base['media_movel'])]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %% [markdown]
# ##**5.3-Tratamento dos valores nulos (iguais a 0)**

# %%
#valores nulos
(base_teste == 0).sum()
# Out:
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume         0
# media_movel    0
# dtype: int64

# %%
#Encontrando os valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %%
#preenchendo os valores nulos com o valor médio
imputer = SimpleImputer(missing_values=0, strategy='mean',verbose=0)
imputer = imputer.fit(base_teste.iloc[:,0:7])
base_teste.iloc[:,0:7] = imputer.transform(base_teste.iloc[:,0:7])

# %%
#Verificando novamente se tem valores nulos
base_teste.loc[base_teste['Volume'] == 0]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, media_movel]
# Index: []

# %% [markdown]
# ##**5.4-Preparando a estrutura para teste**

# %%
#concatenando a base de dados teste com o base de treinamento
preco_real_teste = base_teste.iloc[:, 3:4].values
frames = [base, base_teste]
base_completa = pd.concat(frames)

# %%
#pegando os 90 registros anteriores para percorrer a base teste e colocando no
#no formato np.array
entradas = base_completa[len(base_completa) - len(base_teste) - 90:].values
entradas = normalizador.transform(entradas)
Percorrer_teste = []
for i in range(90, 338): 
    Percorrer_teste.append(entradas[i-90:i, 0:7])
Percorrer_teste = np.array(Percorrer_teste)

# %%
#resultado da predição no formato MinMaxScaler
previsoes = regressor.predict(Percorrer_teste)

# %%
#convertendo para a escala MinMaxScaler 
normalizador_previsao = MinMaxScaler(feature_range=(0,1))
normalizador_previsao.fit_transform(base_treinamento[:,3:4])
# Out:
# array([[0.32860083],
#        [0.32426404],
#        [0.31775871],
#        ...,
#        [0.94376466],
#        [0.98967103],
#        [0.34560447]])

# %%
#colocando a previsão no formato original para preparar a visualização no gráfico
previsoes = normalizador_previsao.inverse_transform(previsoes)
previsoes
# Out:
# array([[23.869808],
#        [24.411854],
#        [25.7746  ],
#        [26.830551],
#        [27.626768],
#        [28.027914],
#        [28.321192],
#        [28.533718],
#        [28.641949],
#        [28.747059],
#        [28.851273],
#        [28.943243],
#        [29.037088],
#        [29.114716],
#        [29.181232],
#        [29.22402 ],
#        [29.25283 ],
#        [29.275267],
#        [29.290413],
#        [29.300018],
#        [29.30404 ],
#        [29.299028],
#        [29.298105],
#        [29.292097],
#        [29.28569 ],
#        [29.279428],
#        [29.26498 ],
#        [29.245491],
#        [29.22412 ],
#        [29.198465],
#        [29.174541],
#        [29.139393],
#        [29.100698],
#        [29.059748],
#        [28.99611 ],
#        [28.90205 ],
#        [28.78557 ],
#        [28.642979],
#        [28.461077],
#        [28.25159 ],
#        [28.033127],
#        [27.764442],
#        [27.446487],
#        [27.203035],
#        [27.493725],
#        [28.45396 ],
#        [29.105326],
#        [29.256546],
#        [29.289898],
#        [29.300726],
#        [29.30533 ],
#        [29.312323],
#        [29.3185  ],
#        [29.320854],
#        [29.32336 ],
#        [29.317904],
#        [29.308743],
#        [29.302153],
#        [29.288698],
#        [29.28265 ],
#        [29.283802],
#        [29.288498],
#        [29.291718],
#        [29.293182],
#        [29.294458],
#        [29.295956],
#        [29.296154],
#        [29.293898],
#        [29.29131 ],
#        [29.285154],
#        [29.27766 ],
#        [29.268606],
#        [29.257296],
#        [29.245024],
#        [29.240181],
#        [29.23829 ],
#        [29.24297 ],
#        [29.24309 ],
#        [29.24611 ],
#        [29.258028],
#        [29.286535],
#        [29.307375],
#        [29.315147],
#        [29.31761 ],
#        [29.315445],
#        [29.309427],
#        [29.309679],
#        [29.30755 ],
#        [29.307703],
#        [29.306263],
#        [29.30304 ],
#        [29.298021],
#        [29.291477],
#        [29.28561 ],
#        [29.283024],
#        [29.288507],
#        [29.294409],
#        [29.297718],
#        [29.299196],
#        [29.299658],
#        [29.300684],
#        [29.303005],
#        [29.306005],
#        [29.307352],
#        [29.305481],
#        [29.30467 ],
#        [29.300255],
#        [29.299988],
#        [29.303734],
#        [29.305155],
#        [29.311357],
#        [29.316713],
#        [29.318535],
#        [29.319681],
#        [29.32013 ],
#        [29.322275],
#        [29.322914],
#        [29.325645],
#        [29.329205],
#        [29.331303],
#        [29.333858],
#        [29.334948],
#        [29.335861],
#        [29.336206],
#        [29.335155],
#        [29.333614],
#        [29.333488],
#        [29.333443],
#        [29.333677],
#        [29.334711],
#        [29.33492 ],
#        [29.334497],
#        [29.333   ],
#        [29.331043],
#        [29.328257],
#        [29.327091],
#        [29.324749],
#        [29.323008],
#        [29.321722],
#        [29.324284],
#        [29.322765],
#        [29.318201],
#        [29.31027 ],
#        [29.294878],
#        [29.273035],
#        [29.24318 ],
#        [29.214195],
#        [29.189636],
#        [29.175367],
#        [29.166643],
#        [29.166456],
#        [29.16158 ],
#        [29.142496],
#        [29.126734],
#        [29.088833],
#        [29.054522],
#        [29.031599],
#        [29.002508],
#        [28.987122],
#        [29.008984],
#        [29.011257],
#        [28.995361],
#        [28.998524],
#        [29.004206],
#        [29.011314],
#        [29.045303],
#        [29.089397],
#        [29.119017],
#        [29.12412 ],
#        [29.135908],
#        [29.15751 ],
#        [29.188427],
#        [29.221884],
#        [29.24111 ],
#        [29.256332],
#        [29.264236],
#        [29.266642],
#        [29.264837],
#        [29.27124 ],
#        [29.281404],
#        [29.289291],
#        [29.297365],
#        [29.302872],
#        [29.305408],
#        [29.30516 ],
#        [29.305998],
#        [29.30621 ],
#        [29.30519 ],
#        [29.303782],
#        [29.294964],
#        [29.287933],
#        [29.284824],
#        [29.283155],
#        [29.278866],
#        [29.27673 ],
#        [29.27493 ],
#        [29.271782],
#        [29.26404 ],
#        [29.254292],
#        [29.245264],
#        [29.237686],
#        [29.213226],
#        [29.183092],
#        [29.172926],
#        [29.181536],
#        [29.19391 ],
#        [29.20846 ],
#        [29.23126 ],
#        [29.250668],
#        [29.268587],
#        [29.274483],
#        [29.278961],
#        [29.282701],
#        [29.290176],
#        [29.297108],
#        [29.306452],
#        [29.311213],
#        [29.314459],
#        [29.317053],
#        [29.317112],
#        [29.316042],
#        [29.31393 ],
#        [29.309483],
#        [29.304836],
#        [29.300598],
#        [29.296799],
#        [29.288895],
#        [29.282309],
#        [29.27265 ],
#        [29.259615],
#        [29.249895],
#        [29.241192],
#        [29.232246],
#        [29.22397 ],
#        [29.213764],
#        [29.204638],
#        [29.19485 ],
#        [29.183449],
#        [29.187136],
#        [29.216642],
#        [29.246862],
#        [29.270727],
#        [29.29304 ],
#        [29.308958],
#        [29.31851 ],
#        [29.324135],
#        [29.327766],
#        [29.330132]], dtype=float32)

# %% [markdown]
# #**6-Análise dos resuldatos**

# %%
#Visualizando o gráfico da Previsão da rede
plt.plot(preco_real_teste, color = 'red', label = 'Preço real')
plt.plot(previsoes, color = 'blue', label = 'Previsões')
plt.title('Previsão do preço das ações')
plt.xlabel('Tempo em dias')
plt.ylabel('Preço das ações')
plt.legend()
plt.show()

# %%
#estatísticas do preço real comparado com a previsão
df1 = pd.DataFrame(preco_real_teste).T
df2 = pd.DataFrame(previsoes).T

df3 = pd.concat([df1,df2]).T
df3.columns = ['Preco real', 'Previsoes']
df3.describe()
# Out:
#        Preco real   Previsoes
# count  248.000000  248.000000
# mean    32.114413   29.116267
# std      1.571007    0.606772
# min     28.760000   23.869808
# 25%     30.940000   29.192842
# 50%     31.965000   29.283090
# 75%     33.200000   29.306223
# max     35.830000   29.336206

# %%
#df2 = pd.DataFrame(previsoes)
#df2.describe()

# %%
#df1 = pd.DataFrame(preco_real_teste)
#df1.describe()
